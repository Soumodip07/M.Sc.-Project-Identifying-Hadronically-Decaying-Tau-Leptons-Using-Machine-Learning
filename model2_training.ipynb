# %% [markdown]
# # Model 2 training ($E_{cm} = 200$ GeV)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import AUC, Precision, Recall

# %%
drive_dir = Path('/content/drive/MyDrive/Jet_classification_project/Training_Datasets_Models_Results')

jet_images_path = drive_dir / 'Dataset2_75k_200GeV/jet_images.npy'
jet_labels_path = drive_dir / 'Dataset2_75k_200GeV/jet_labels.npy'

model_save_path = drive_dir / 'Dataset2_Model_and_Results/Model2_200GeV.keras'

metrics_path = drive_dir / 'Dataset2_Model_and_Results'

# %%
X = np.load(jet_images_path)
y = np.load(jet_labels_path)

if len(X.shape) == 3:
    X = X[..., np.newaxis]

input_shape = X.shape[1:]

print(f"Loaded {X.shape[0]} jet images with shape {input_shape} and {len(np.unique(y))} classes.")
print(f"Labels shape: {y.shape}\n")

print(f"Final Images shape: {X.shape}")
print(f"Pixel Intensity Range: Min = {X.min()}, Max = {X.max()}")
# Out:
# Loaded 235845 jet images with shape (32, 32, 1) and 2 classes.
# Labels shape: (235845,)
#
# Final Images shape: (235845, 32, 32, 1)
# Pixel Intensity Range: Min = 0.0, Max = 1.0

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=31, stratify=y)

print(f"Train set:      {X_train.shape[0]} samples")
print(f"Validation set: {X_val.shape[0]} samples")
# Out:
# Train set:      165091 samples
# Validation set: 70754 samples

# %%
model = models.Sequential()

model.add(layers.Input(shape=input_shape))

model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())

model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 504,065 (1.92 MB)
#  Trainable params: 503,361 (1.92 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-5,
    decay_steps=1500,
    decay_rate=0.95)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))
print("Class Weights:", class_weights_dict)

model.compile(optimizer=optimizer, loss='binary_crossentropy',
              metrics=['accuracy', AUC(name='auc'), Precision(name='precision'), Recall(name='recall')])

print("\nModel Compiled Successfully!\n")

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

checkpoint = ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True)

batch_size = 64
epochs = 120

history = model.fit(X_train, y_train,
                     epochs=epochs,
                     batch_size=batch_size,
                     validation_data=(X_val, y_val),
                     class_weight=class_weights_dict,
                     callbacks=[early_stopping, checkpoint])

print(f"\nModel saved to {model_save_path}")
# Out:
# Class Weights: {0: np.float64(1.1120983496126642), 1: np.float64(0.908431096339665)}
#
# Model Compiled Successfully!
#
# Epoch 1/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━
120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9722 - auc: 0.9940 - loss: 0.0839 - precision: 0.9716 - recall: 0.9782 - val_accuracy: 0.9694 - val_auc: 0.9938 - val_loss: 0.0878 - val_precision: 0.9713 - val_recall: 0.9731
# Epoch 44/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.9715 - auc: 0.9939 - loss: 0.0855 - precision: 0.9714 - recall: 0.9771 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0868 - val_precision: 0.9683 - val_recall: 0.9767
# Epoch 45/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.9713 - auc: 0.9936 - loss: 0.0859 - precision: 0.9709 - recall: 0.9772 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0867 - val_precision: 0.9681 - val_recall: 0.9770
# Epoch 46/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.9724 - auc: 0.9941 - loss: 0.0833 - precision: 0.9715 - recall: 0.9785 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0869 - val_precision: 0.9690 - val_recall: 0.9760
# Epoch 47/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.9720 - auc: 0.9941 - loss: 0.0842 - precision: 0.9715 - recall: 0.9777 - val_accuracy: 0.9697 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9677 - val_recall: 0.9776
# Epoch 48/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - accuracy: 0.9713 - auc: 0.9938 - loss: 0.0851 - precision: 0.9707 - recall: 0.9774 - val_accuracy: 0.9698 - val_auc: 0.9937 - val_loss: 0.0868 - val_precision: 0.9692 - val_recall: 0.9761
# Epoch 49/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9717 - auc: 0.9939 - loss: 0.0842 - precision: 0.9718 - recall: 0.9770 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9670 - val_recall: 0.9782
# Epoch 50/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9717 - auc: 0.9937 - loss: 0.0853 - precision: 0.9709 - recall: 0.9779 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9678 - val_recall: 0.9772
# Epoch 51/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - accuracy: 0.9716 - auc: 0.9939 - loss: 0.0839 - precision: 0.9709 - recall: 0.9776 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0867 - val_precision: 0.9684 - val_recall: 0.9766
# Epoch 52/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9720 - auc: 0.9939 - loss: 0.0848 - precision: 0.9715 - recall: 0.9779 - val_accuracy: 0.9696 - val_auc: 0.9938 - val_loss: 0.0866 - val_precision: 0.9678 - val_recall: 0.9773
# Epoch 53/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - accuracy: 0.9717 - auc: 0.9939 - loss: 0.0846 - precision: 0.9708 - recall: 0.9779 - val_accuracy: 0.9695 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9680 - val_recall: 0.9769
# Epoch 54/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9716 - auc: 0.9939 - loss: 0.0849 - precision: 0.9705 - recall: 0.9780 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9678 - val_recall: 0.9774
# Epoch 55/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.9717 - auc: 0.9941 - loss: 0.0837 - precision: 0.9710 - recall: 0.9777 - val_accuracy: 0.9696 - val_auc: 0.9938 - val_loss: 0.0867 - val_precision: 0.9684 - val_recall: 0.9766
# Epoch 56/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - accuracy: 0.9714 - auc: 0.9938 - loss: 0.0852 - precision: 0.9706 - recall: 0.9775 - val_accuracy: 0.9697 - val_auc: 0.9937 - val_loss: 0.0868 - val_precision: 0.9692 - val_recall: 0.9759
# Epoch 57/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.9721 - auc: 0.9943 - loss: 0.0828 - precision: 0.9724 - recall: 0.9772 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0867 - val_precision: 0.9686 - val_recall: 0.9765
# Epoch 58/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9719 - auc: 0.9939 - loss: 0.0848 - precision: 0.9713 - recall: 0.9779 - val_accuracy: 0.9698 - val_auc: 0.9938 - val_loss: 0.0867 - val_precision: 0.9692 - val_recall: 0.9761
# Epoch 59/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9721 - auc: 0.9939 - loss: 0.0840 - precision: 0.9708 - recall: 0.9786 - val_accuracy: 0.9697 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9685 - val_recall: 0.9767
# Epoch 60/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9717 - auc: 0.9938 - loss: 0.0850 - precision: 0.9713 - recall: 0.9775 - val_accuracy: 0.9696 - val_auc: 0.9937 - val_loss: 0.0867 - val_precision: 0.9685 - val_recall: 0.9765
# Epoch 61/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9717 - auc: 0.9939 - loss: 0.0848 - precision: 0.9710 - recall: 0.9779 - val_accuracy: 0.9697 - val_auc: 0.9937 - val_loss: 0.0868 - val_precision: 0.9695 - val_recall: 0.9758
# Epoch 62/120
# 2580/2580 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.9726 - auc: 0.9940 - loss: 0.0831 - precision: 0.9723 - recall: 0.9781 - val_accuracy: 0.9697 - val_auc: 0.9937 - val_loss: 0.0866 - val_precision: 0.9685 - val_recall: 0.9767
#
# Model saved to /content/drive/MyDrive/Jet_classification_project/Training_Datasets_Models_Results/Dataset2_Model_and_Results/Model2_200GeV.keras

# %%
# Accuracy Plot
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', lw=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', lw=2)

plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.minorticks_on()

plt.tick_params(axis='both', which='major', length=8)
plt.tick_params(axis='both', which='minor', length=4)

plt.grid(True, which='major', linestyle='--', linewidth=0.8, alpha=0.6)
plt.grid(True, which='minor', linestyle=':', linewidth=0.5, alpha=0.4)

plt.legend(loc='best', fontsize=12, frameon=False)
plt.tight_layout()

plt.savefig(f'{metrics_path}/training_vs_val_acc.png', dpi=300)
plt.show()

# %%
# Loss Plot
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss', lw=2)
plt.plot(history.history['val_loss'], label='Validation Loss', lw=2)

plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)

plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.minorticks_on()

plt.tick_params(axis='both', which='major', length=8)
plt.tick_params(axis='both', which='minor', length=4)

plt.grid(True, which='major', linestyle='--', linewidth=0.8, alpha=0.6)
plt.grid(True, which='minor', linestyle=':', linewidth=0.5, alpha=0.4)

plt.legend(loc='best', fontsize=12, frameon=False)
plt.tight_layout()

plt.savefig(f'{metrics_path}/training_vs_val_loss.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(7, 5))
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Training vs Validation Precision')
plt.legend(loc = 'best', fontsize=12, frameon = False)
plt.grid(True)
plt.tight_layout()
plt.savefig(f'{metrics_path}/training_vs_val_precision.png')
plt.show()

plt.figure(figsize=(7, 5))
plt.plot(history.history['recall'], label='Training Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Training vs Validation Recall')
plt.legend(loc = 'best', fontsize=12, frameon = False)
plt.grid(True)
plt.tight_layout()
plt.savefig(f'{metrics_path}/training_vs_val_recall.png')
plt.show()

# %%
plt.figure(figsize=(7, 5))
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Training vs Validation AUC')
plt.legend(loc = 'best', fontsize=12, frameon = False)
plt.grid(True)
plt.tight_layout()
plt.savefig(f'{metrics_path}/training_vs_val_AUC.png')
plt.show()
